# %% [markdown]
# Testing various partial derivative related membership algorithms on a randomly generated regular expression.
# This is the next generation of testing beyond `docs/pdOptimizations.py` and `docs/pd_results_saved.rtf`.

# %%
import time
import cProfile
import pstats
from benchmark.convert import Converter

arbitrary_re = "(((((((((e g) a) ((f a) + c)) (@any (b + d?))) ((((a f) j) + @any) + ((c + ((((j? ((((h + ((d d) (([^df-g]* + d) (d [ab-cdefg-hij])))) (j? + i)) + [acd-eghj]) + (h + f))) + ((h (a + g)) + ((i + (c (c + ((c + (@any + ((((@any + @any)? c)* + h) + ((g + i) + h)))) @any))?)?) (((d + ((i j?) g)*) ((@any + ((g [c-gij])* j)) + [bde-gh-ij])) j)))) (h b)) ((a b?) + ((i + (i d)?) c*)))) d)))* d?) d) + (c? + [b-cd-ehj])) + d)"
re = Converter().math(arbitrary_re)
words = re.pairGen()
print "Generated", len(words), "accepting words with average length", sum(map(lambda w: len(w), words))*1.0/len(words)

def testit(evalFtn):
    profiler = cProfile.Profile()
    profiler.enable()
    
    t0 = time.time()
    for word in words:
        assert evalFtn(re, word)
    tf = time.time()
    
    profiler.disable()
    print "Took", tf - t0, "seconds"

    stats = pstats.Stats(profiler)
    stats.strip_dirs()
    stats.sort_stats("cumulative")
    stats.print_stats()
# Out:
# Generated 408 accepting words with average length 425.303921569

# %%
# PDDAG Construction, then evaluate word membership
testit(lambda re, word: re.nfaPDDAG().evalWordP(word))
# Out:
# Took 10.1835949421 seconds
#          18701644 function calls (17929670 primitive calls) in 10.183 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       408    0.006    0.000   10.183    0.025 <ipython-input-6-b85210a69a57>:2(<lambda>)
#       408    0.072    0.000    5.596    0.014 pddag.py:266(pddag)
#       408    0.067    0.000    4.581    0.011 fa.py:2156(evalWordP)
#    173524    1.133    0.000    4.512    0.000 fa_ext.py:57(evalSymbol)
#       408    0.001    0.000    4.500    0.011 pddag.py:77(__init__)
# 61200/408    0.077    0.000    4.496    0.011 pddag.py:89(getIdx)
# 275808/16728    0.623    0.000    3.761    0.000 pddag.py:160(getConcatIdx)
# 106080/18360    0.319    0.000    3.609    0.000 pddag.py:214(catLF)
# 239088/35904    0.155    0.000    3.115    0.000 pddag.py:219(<setcomp>)
#    735216    0.260    0.000    3.005    0.000 reex.py:378(__hash__)
#    735216    0.230    0.000    2.685    0.000 {repr}
#    622200    0.398    0.000    2.122    0.000 reex_ext.py:912(__repr__)
#    823344    1.384    0.000    2.030    0.000 reex_ext.py:900(__str__)
#    598818    0.367    0.000    1.563    0.000 reex_ext.py:915(derivative)
#    791191    0.401    0.000    1.036    0.000 reex.py:1383(__init__)
#       408    0.089    0.000    1.024    0.003 pddag.py:244(NFA)
#    523595    0.270    0.000    0.955    0.000 reex_ext.py:879(__init__)
#     52224    0.040    0.000    0.684    0.000 fa_ext.py:72(addTransition)
#     20400    0.085    0.000    0.682    0.000 pddag.py:222(plusLF)
#     52224    0.081    0.000    0.644    0.000 fa.py:1976(addTransition)
#     80599    0.060    0.000    0.639    0.000 reex_ext.py:1114(derivative)
#    791191    0.405    0.000    0.635    0.000 reex_ext.py:11(__init__)
#    319115    0.441    0.000    0.583    0.000 fa.py:2086(epsilonClosure)
#      2448    0.007    0.000    0.553    0.000 pddag.py:125(getStarIdx)
#      2448    0.003    0.000    0.505    0.000 pddag.py:234(doDelayed)
#    267596    0.144    0.000    0.495    0.000 reex_ext.py:818(__init__)
#     12648    0.039    0.000    0.492    0.000 pddag.py:186(getDisjIdx)
#     80599    0.037    0.000    0.425    0.000 reex_ext.py:1111(__contains__)
#     80599    0.054    0.000    0.388    0.000 util.py:212(indexOf)
#    823344    0.340    0.000    0.340    0.000 {hasattr}
#    113016    0.070    0.000    0.333    0.000 reex_ext.py:1108(__repr__)
#   1008915    0.107    0.000    0.308    0.000 {method 'get' of 'dict' objects}
#    823344    0.307    0.000    0.307    0.000 {method 'encode' of 'unicode' objects}
#    649595    0.072    0.000    0.271    0.000 {method 'add' of 'set' objects}
#     88128    0.041    0.000    0.253    0.000 reex_ext.py:1242(__hash__)
#    111774    0.043    0.000    0.246    0.000 reex_ext.py:1245(derivative)
#    128928    0.234    0.000    0.234    0.000 pddag.py:43(__init__)
#    791191    0.230    0.000    0.230    0.000 reex.py:54(__init__)
#     80599    0.140    0.000    0.230    0.000 util.py:191(search)
#    288048    0.191    0.000    0.191    0.000 {method 'intersection' of 'set' objects}
#    725521    0.182    0.000    0.182    0.000 reex.py:367(__eq__)
#    622200    0.163    0.000    0.163    0.000 {method 'format' of 'str' objects}
# 643492/482294    0.093    0.000    0.133    0.000 {len}
#     80599    0.048    0.000    0.105    0.000 util.py:221(indexContains)
#    598818    0.102    0.000    0.102    0.000 reex_ext.py:936(__contains__)
#    905418    0.098    0.000    0.098    0.000 {method 'update' of 'set' objects}
#     68544    0.045    0.000    0.085    0.000 fa.py:404(stateIndex)
#     27336    0.023    0.000    0.071    0.000 pddag.py:110(getAtomIdx)
#    823344    0.067    0.000    0.067    0.000 {hash}
#    318461    0.065    0.000    0.065    0.000 {method 'items' of 'dict' objects}
#    161198    0.041    0.000    0.056    0.000 util.py:185(__len__)
#    509243    0.041    0.000    0.041    0.000 {method 'pop' of 'set' objects}
#    302232    0.038    0.000    0.038    0.000 util.py:182(__getitem__)
#     52224    0.017    0.000    0.033    0.000 reex.py:374(__ne__)
#    103632    0.030    0.000    0.030    0.000 pddag.py:204(ewpFixConc)
#     52632    0.023    0.000    0.023    0.000 {method 'index' of 'list' objects}
#    117894    0.022    0.000    0.022    0.000 reex_ext.py:1239(__eq__)
#    127704    0.020    0.000    0.020    0.000 {isinstance}
#     16320    0.014    0.000    0.018    0.000 fa.py:255(addState)
#      4488    0.006    0.000    0.012    0.000 pddag.py:143(getOptionIdx)
#     52224    0.009    0.000    0.009    0.000 {method 'union' of 'set' objects}
#     12240    0.005    0.000    0.005    0.000 pddag.py:209(ewpFixDisj)
#       408    0.002    0.000    0.004    0.000 fa_ext.py:34(__init__)
#     16320    0.003    0.000    0.003    0.000 {method 'append' of 'list' objects}
#       816    0.001    0.000    0.002    0.000 fa.py:1537(__init__)
#       816    0.001    0.000    0.001    0.000 fa.py:97(__init__)
#       816    0.000    0.000    0.000    0.000 fa.py:369(addFinal)
#       408    0.000    0.000    0.000    0.000 fa.py:1910(addInitial)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {time.time}

# %%
# PDRPN Construction, then evaluate word membership
testit(lambda re, word: re.nfaPDRPN().evalWordP(word))
# Out:
# Took 6.10067200661 seconds
#          12611836 function calls (12282134 primitive calls) in 6.100 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       408    0.006    0.000    6.100    0.015 <ipython-input-7-c2f9f7ca0e1b>:2(<lambda>)
#       408    0.066    0.000    4.562    0.011 fa.py:2156(evalWordP)
#    173524    1.115    0.000    4.494    0.000 fa_ext.py:57(evalSymbol)
#    598818    0.370    0.000    1.571    0.000 reex_ext.py:915(derivative)
#       408    0.166    0.000    1.532    0.004 reex_ext.py:61(nfaPDRPN)
#    791191    0.397    0.000    1.040    0.000 reex.py:1383(__init__)
#    523595    0.271    0.000    0.963    0.000 reex_ext.py:879(__init__)
#     52224    0.043    0.000    0.693    0.000 fa_ext.py:72(addTransition)
#     52224    0.082    0.000    0.651    0.000 fa.py:1976(addTransition)
#    791599    0.416    0.000    0.644    0.000 reex_ext.py:11(__init__)
#     80599    0.059    0.000    0.633    0.000 reex_ext.py:1114(derivative)
#    165240    0.057    0.000    0.632    0.000 reex.py:378(__hash__)
#    319115    0.441    0.000    0.578    0.000 fa.py:2086(epsilonClosure)
#    192576    0.053    0.000    0.565    0.000 {repr}
#    267596    0.144    0.000    0.492    0.000 reex_ext.py:818(__init__)
#    143208    0.091    0.000    0.449    0.000 reex_ext.py:912(__repr__)
#     80599    0.036    0.000    0.421    0.000 reex_ext.py:1111(__contains__)
#    185640    0.276    0.000    0.416    0.000 reex_ext.py:900(__str__)
#     80599    0.052    0.000    0.385    0.000 util.py:212(indexOf)
#    383987    0.046    0.000    0.249    0.000 {method 'add' of 'set' objects}
#    111774    0.043    0.000    0.247    0.000 reex_ext.py:1245(derivative)
#     80599    0.139    0.000    0.228    0.000 util.py:191(search)
#    791599    0.228    0.000    0.228    0.000 reex.py:54(__init__)
#    725521    0.181    0.000    0.181    0.000 reex.py:367(__eq__)
# 63648/49776    0.035    0.000    0.124    0.000 reex_ext.py:470(_memoRPN)
# 355444/194246    0.074    0.000    0.118    0.000 {len}
#    379032    0.116    0.000    0.116    0.000 {hasattr}
# 13872/1224    0.018    0.000    0.108    0.000 reex_ext.py:563(_memoRPN)
#    124848    0.062    0.000    0.106    0.000 fa.py:404(stateIndex)
#     52632    0.060    0.000    0.106    0.000 fa.py:255(addState)
#     80599    0.048    0.000    0.105    0.000 util.py:221(indexContains)
#    598818    0.103    0.000    0.103    0.000 reex_ext.py:936(__contains__)
#  2448/408    0.002    0.000    0.096    0.000 reex_ext.py:729(_memoRPN)
#    905826    0.095    0.000    0.095    0.000 {method 'update' of 'set' objects}
#    956691    0.087    0.000    0.087    0.000 {method 'get' of 'dict' objects}
# 111384/15504    0.053    0.000    0.071    0.000 reex.py:2802(ewp)
#    185640    0.068    0.000    0.068    0.000 {method 'encode' of 'unicode' objects}
#    318461    0.067    0.000    0.067    0.000 {method 'items' of 'dict' objects}
#     22032    0.013    0.000    0.063    0.000 reex_ext.py:1108(__repr__)
# 12648/408    0.013    0.000    0.057    0.000 reex_ext.py:557(_delAttr)
#     20400    0.009    0.000    0.057    0.000 reex_ext.py:1242(__hash__)
#    161198    0.041    0.000    0.055    0.000 util.py:185(__len__)
# 14280/408    0.015    0.000    0.054    0.000 reex_ext.py:464(_delAttr)
#  2448/408    0.002    0.000    0.051    0.000 reex_ext.py:724(_delAttr)
#     28560    0.014    0.000    0.050    0.000 reex_ext.py:1051(_memoRPN)
#    124848    0.044    0.000    0.044    0.000 {method 'index' of 'list' objects}
#    302232    0.039    0.000    0.039    0.000 util.py:182(__getitem__)
#    143208    0.038    0.000    0.038    0.000 {method 'format' of 'str' objects}
#     52224    0.018    0.000    0.034    0.000 reex.py:374(__ne__)
# 4488/3672    0.004    0.000    0.028    0.000 reex_ext.py:811(_memoRPN)
#    319115    0.026    0.000    0.026    0.000 {method 'pop' of 'set' objects}
# 20400/6528    0.013    0.000    0.025    0.000 reex.py:2006(ewp)
#     27336    0.015    0.000    0.025    0.000 reex_ext.py:1044(rpn)
#   816/408    0.003    0.000    0.023    0.000 reex.py:2115(_memoLF)
#    117894    0.023    0.000    0.023    0.000 reex_ext.py:1239(__eq__)
#     16320    0.015    0.000    0.018    0.000 util.py:449(pop_left)
#     27336    0.009    0.000    0.015    0.000 reex_ext.py:1047(_delAttr)
#    185640    0.015    0.000    0.015    0.000 {hash}
# 4488/3672    0.003    0.000    0.015    0.000 reex_ext.py:806(_delAttr)
#     16320    0.011    0.000    0.011    0.000 util.py:431(insert_right)
#     36312    0.009    0.000    0.009    0.000 common.py:153(__init__)
#     61200    0.007    0.000    0.007    0.000 {delattr}
#     15096    0.004    0.000    0.007    0.000 reex_ext.py:372(_memoLF)
#     27336    0.006    0.000    0.006    0.000 {method 'replace' of 'unicode' objects}
#     34272    0.004    0.000    0.004    0.000 reex.py:328(ewp)
#       408    0.001    0.000    0.004    0.000 reex_ext.py:533(compress)
#       408    0.001    0.000    0.003    0.000 fa_ext.py:34(__init__)
#     16320    0.003    0.000    0.003    0.000 util.py:416(isEmpty)
#     16728    0.003    0.000    0.003    0.000 util.py:413(__len__)
#     16320    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#       408    0.001    0.000    0.002    0.000 reex_ext.py:478(__init__)
#       816    0.001    0.000    0.002    0.000 fa.py:1537(__init__)
#       408    0.001    0.000    0.002    0.000 util.py:381(__init__)
#       408    0.001    0.000    0.001    0.000 reex.py:1857(__init__)
#      2040    0.001    0.000    0.001    0.000 reex_ext.py:873(_memoRPN)
#      7752    0.001    0.000    0.001    0.000 reex.py:2691(ewp)
#       816    0.001    0.000    0.001    0.000 fa.py:97(__init__)
#      5304    0.001    0.000    0.001    0.000 reex.py:2469(ewp)
#       816    0.000    0.000    0.000    0.000 reex_ext.py:989(_memoLF)
#       816    0.000    0.000    0.000    0.000 fa.py:369(addFinal)
#       408    0.000    0.000    0.000    0.000 fa.py:1910(addInitial)
#       408    0.000    0.000    0.000    0.000 reex.py:1551(_memoLF)
#       408    0.000    0.000    0.000    0.000 reex.py:1670(ewp)
#         2    0.000    0.000    0.000    0.000 {time.time}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
# PDO Construction, then evaluate word membership
testit(lambda re, word: re.nfaPDO().evalWordP(word))
# Out:
# Took 336.902625084 seconds
#          665095228 function calls (401687942 primitive calls) in 336.855 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       408    0.043    0.000  336.855    0.826 <ipython-input-8-38d993d52793>:2(<lambda>)
#       408    0.003    0.000  332.357    0.815 reex_ext.py:56(nfaPDO)
#       408    0.280    0.001  332.352    0.815 reex.py:521(nfaPDO)
# 175514664/2035920   49.194    0.000  326.755    0.000 {repr}
# 76699104/1059984   51.931    0.000  323.241    0.000 reex.py:1863(__repr__)
# 7720992/3084072    4.780    0.000  249.916    0.000 reex_ext.py:641(__repr__)
# 7720992/3084072    3.165    0.000  247.968    0.000 reex.py:2530(__repr__)
#   1216345    0.665    0.000  236.745    0.000 reex.py:367(__eq__)
#     16320    0.178    0.000  192.059    0.012 fa.py:255(addState)
#  64455840   35.159    0.000  187.725    0.000 reex_ext.py:912(__repr__)
#  70889184   99.789    0.000  151.386    0.000 reex_ext.py:900(__str__)
#   1221552    0.497    0.000   91.767    0.000 reex.py:378(__hash__)
# 12359544/10219584    7.299    0.000   89.995    0.000 reex_ext.py:750(__repr__)
# 12359544/10219584    4.608    0.000   83.921    0.000 reex.py:2372(__repr__)
# 106896/15504    1.223    0.000   60.817    0.004 reex_ext.py:372(_memoLF)
#    720179    0.225    0.000   56.432    0.000 {method 'add' of 'set' objects}
#  71112768   27.248    0.000   27.248    0.000 {hasattr}
#  70889184   24.421    0.000   24.421    0.000 {method 'encode' of 'unicode' objects}
#   6331344    3.318    0.000   17.367    0.000 reex_ext.py:1108(__repr__)
#  64455840   15.463    0.000   15.463    0.000 {method 'format' of 'str' objects}
#       408    0.065    0.000    4.455    0.011 fa.py:2156(evalWordP)
#    173524    1.101    0.000    4.388    0.000 fa_ext.py:57(evalSymbol)
# 14280/5304    0.115    0.000    3.360    0.001 reex.py:2115(_memoLF)
#    598818    0.361    0.000    1.530    0.000 reex_ext.py:915(derivative)
#    818527    0.412    0.000    1.072    0.000 reex.py:1383(__init__)
#     52224    0.139    0.000    0.967    0.000 fa.py:1976(addTransition)
#   1081279    0.606    0.000    0.949    0.000 reex_ext.py:11(__init__)
#    523595    0.265    0.000    0.937    0.000 reex_ext.py:879(__init__)
#    262752    0.211    0.000    0.769    0.000 reex_ext.py:308(__init__)
#   7942128    0.684    0.000    0.684    0.000 reex_ext.py:1236(__repr__)
#     80599    0.058    0.000    0.620    0.000 reex_ext.py:1114(derivative)
#   1354968    0.607    0.000    0.607    0.000 {hash}
#    294932    0.165    0.000    0.565    0.000 reex_ext.py:818(__init__)
#    319115    0.429    0.000    0.561    0.000 fa.py:2086(epsilonClosure)
#    262752    0.268    0.000    0.558    0.000 reex.py:1857(__init__)
#      4896    0.013    0.000    0.518    0.000 reex_ext.py:625(_memoLF)
#     40800    0.040    0.000    0.422    0.000 fa.py:391(addSigma)
#     80599    0.035    0.000    0.412    0.000 reex_ext.py:1111(__contains__)
#     80599    0.052    0.000    0.377    0.000 util.py:212(indexOf)
# 4896/4488    0.005    0.000    0.348    0.000 reex.py:2451(_memoLF)
#   1081279    0.343    0.000    0.343    0.000 reex.py:54(__init__)
# 470832/102000    0.199    0.000    0.303    0.000 reex.py:2802(ewp)
#    102000    0.049    0.000    0.292    0.000 reex_ext.py:1242(__hash__)
#     31416    0.024    0.000    0.287    0.000 reex_ext.py:989(_memoLF)
#     27336    0.042    0.000    0.251    0.000 reex_ext.py:933(linearForm)
#    111774    0.042    0.000    0.240    0.000 reex_ext.py:1245(derivative)
#     80599    0.136    0.000    0.221    0.000 util.py:191(search)
# 120360/44472    0.075    0.000    0.137    0.000 reex.py:2006(ewp)
# 338716/177518    0.071    0.000    0.110    0.000 {len}
#     80599    0.047    0.000    0.103    0.000 util.py:221(indexContains)
#    598818    0.101    0.000    0.101    0.000 reex_ext.py:936(__contains__)
#    914802    0.093    0.000    0.095    0.000 {method 'update' of 'set' objects}
#    956691    0.081    0.000    0.081    0.000 {method 'get' of 'dict' objects}
# 12648/408    0.012    0.000    0.069    0.000 reex_ext.py:557(_delAttr)
# 14280/408    0.014    0.000    0.065    0.000 reex_ext.py:464(_delAttr)
#  2448/408    0.002    0.000    0.063    0.000 reex_ext.py:724(_delAttr)
#    318461    0.060    0.000    0.060    0.000 {method 'items' of 'dict' objects}
#    161198    0.039    0.000    0.054    0.000 util.py:185(__len__)
#     52224    0.030    0.000    0.053    0.000 reex.py:374(__ne__)
#    295392    0.042    0.000    0.042    0.000 reex.py:133(emptysetP)
#    302232    0.038    0.000    0.038    0.000 util.py:182(__getitem__)
#    262752    0.030    0.000    0.030    0.000 reex.py:322(epsilonP)
#    223176    0.028    0.000    0.028    0.000 reex.py:328(ewp)
#    134214    0.027    0.000    0.027    0.000 reex_ext.py:1239(__eq__)
#    319115    0.026    0.000    0.026    0.000 {method 'pop' of 'set' objects}
#     61200    0.021    0.000    0.021    0.000 {delattr}
#     27336    0.009    0.000    0.021    0.000 reex_ext.py:1047(_delAttr)
# 4488/3672    0.003    0.000    0.017    0.000 reex_ext.py:806(_delAttr)
#     31416    0.011    0.000    0.014    0.000 reex.py:1634(__hash__)
#     53856    0.008    0.000    0.008    0.000 reex.py:2691(ewp)
#     32232    0.008    0.000    0.008    0.000 {method 'append' of 'list' objects}
#     16320    0.006    0.000    0.006    0.000 {method 'pop' of 'list' objects}
#     32640    0.005    0.000    0.005    0.000 reex.py:1643(epsilonP)
#     29376    0.005    0.000    0.005    0.000 reex.py:2469(ewp)
#       816    0.002    0.000    0.003    0.000 fa.py:1537(__init__)
#       408    0.001    0.000    0.003    0.000 fa_ext.py:34(__init__)
#       816    0.001    0.000    0.001    0.000 fa.py:97(__init__)
#       816    0.001    0.000    0.001    0.000 fa.py:369(addFinal)
#      5712    0.001    0.000    0.001    0.000 reex.py:1617(__repr__)
#       408    0.000    0.000    0.000    0.000 fa.py:1910(addInitial)
#       408    0.000    0.000    0.000    0.000 reex.py:1551(_memoLF)
#       408    0.000    0.000    0.000    0.000 reex.py:1670(ewp)
#         2    0.000    0.000    0.000    0.000 {time.time}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
# Implemented direct pd algorithm (same as re.evalWordP_PD)
def implemented(self, word):
    memo = dict() # re.rpn(): {str.sigma: dict(pd.rpn(), pd)}
    current = dict([(self.rpn(), self)])
    for sigma in word:
        nxt = dict()
        for pdstr, pd in current.items():
            if not memo.has_key(pdstr):
                memo[pdstr] = dict([(sigma, dict([(x.rpn(), x) for x in pd.partialDerivatives(sigma)]))])
            elif not memo[pdstr].has_key(sigma):
                memo[pdstr][sigma] = dict([(x.rpn(), x) for x in pd.partialDerivatives(sigma)])
            nxt.update(memo[pdstr][sigma])
        current = nxt
    for pd in current.values():
        if pd.ewp():
            return True
    return False

testit(implemented)
# Out:
# Took 68.6461658478 seconds
#          125029112 function calls (79251249 primitive calls) in 68.571 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       408    0.523    0.001   68.571    0.168 <ipython-input-9-b4f6aeb77262>:2(implemented)
# 344463/41711    0.918    0.000   61.280    0.001 reex_ext.py:340(partialDerivatives)
#    300896    0.138    0.000   57.463    0.000 {method 'add' of 'set' objects}
#    298718    0.173    0.000   57.316    0.000 reex.py:378(__hash__)
# 31219573/3834627    8.562    0.000   57.216    0.000 {repr}
# 12049201/276519    9.706    0.000   56.599    0.000 reex.py:1863(__repr__)
# 1360252/734407    1.010    0.000   40.579    0.000 reex_ext.py:641(__repr__)
# 1360252/734407    0.642    0.000   40.026    0.000 reex.py:2530(__repr__)
#   9989784    6.475    0.000   31.896    0.000 reex_ext.py:912(__repr__)
#  11009475   17.190    0.000   25.339    0.000 reex_ext.py:900(__str__)
# 1926292/1630986    1.370    0.000   15.053    0.000 reex_ext.py:750(__repr__)
# 1926292/1630986    0.871    0.000   13.887    0.000 reex.py:2372(__repr__)
# 2027876/42131    1.801    0.000    6.580    0.000 reex.py:2797(rpn)
# 1447294/211444    1.235    0.000    5.554    0.000 reex.py:2003(rpn)
# 356965/146310    0.194    0.000    5.086    0.000 reex.py:2563(rpn)
#  11009475    4.237    0.000    4.237    0.000 {hasattr}
#  11009475    3.913    0.000    3.913    0.000 {method 'encode' of 'unicode' objects}
#   1017513    0.629    0.000    3.020    0.000 reex_ext.py:1108(__repr__)
#   3517703    1.807    0.000    2.896    0.000 reex_ext.py:1044(rpn)
# 63015/23655    0.081    0.000    2.783    0.000 reex.py:2084(partialDerivatives)
#  10547955    2.611    0.000    2.611    0.000 {method 'format' of 'str' objects}
# 558171/463261    0.327    0.000    1.860    0.000 reex.py:2397(rpn)
#     30181    0.040    0.000    1.215    0.000 reex_ext.py:596(partialDerivatives)
#    151999    0.185    0.000    1.023    0.000 reex_ext.py:918(partialDerivatives)
#    258771    0.318    0.000    0.910    0.000 reex_ext.py:308(__init__)
#   3517703    0.713    0.000    0.713    0.000 {method 'replace' of 'unicode' objects}
# 992856/255141    0.435    0.000    0.694    0.000 reex.py:2802(ewp)
#    258771    0.286    0.000    0.592    0.000 reex.py:1857(__init__)
#    463018    0.328    0.000    0.518    0.000 reex_ext.py:11(__init__)
# 17144/14966    0.010    0.000    0.482    0.000 reex.py:2460(partialDerivatives)
#    106132    0.099    0.000    0.435    0.000 reex_ext.py:915(derivative)
#    204247    0.136    0.000    0.348    0.000 reex.py:1383(__init__)
# 273523/129093    0.181    0.000    0.327    0.000 reex.py:2006(ewp)
#    353144    0.322    0.000    0.322    0.000 {hash}
#     99751    0.113    0.000    0.287    0.000 reex_ext.py:879(__init__)
#    104496    0.075    0.000    0.249    0.000 reex_ext.py:818(__init__)
#    463018    0.191    0.000    0.191    0.000 reex.py:54(__init__)
#     12169    0.014    0.000    0.154    0.000 reex_ext.py:1114(derivative)
#   1340622    0.136    0.000    0.136    0.000 reex_ext.py:1236(__repr__)
#     12169    0.011    0.000    0.111    0.000 reex_ext.py:1111(__contains__)
#     33698    0.020    0.000    0.106    0.000 reex_ext.py:1245(derivative)
#     12169    0.015    0.000    0.099    0.000 util.py:212(indexOf)
#    566369    0.074    0.000    0.074    0.000 reex.py:328(ewp)
#    318461    0.072    0.000    0.072    0.000 {method 'update' of 'dict' objects}
#    625892    0.067    0.000    0.067    0.000 {method 'has_key' of 'dict' objects}
#     12169    0.038    0.000    0.063    0.000 util.py:191(search)
#    109933    0.022    0.000    0.043    0.000 {method 'update' of 'set' objects}
#    300896    0.042    0.000    0.042    0.000 reex.py:133(emptysetP)
#    258771    0.032    0.000    0.032    0.000 reex.py:322(epsilonP)
#     52248    0.022    0.000    0.031    0.000 reex.py:1634(__hash__)
#    197967    0.029    0.000    0.029    0.000 reex.py:2691(ewp)
#    173524    0.029    0.000    0.029    0.000 {method 'items' of 'dict' objects}
#    106132    0.027    0.000    0.027    0.000 reex_ext.py:936(__contains__)
# 48676/24338    0.016    0.000    0.026    0.000 {len}
#     12169    0.011    0.000    0.022    0.000 util.py:221(indexContains)
#      9103    0.010    0.000    0.021    0.000 reex.py:367(__eq__)
#     24338    0.009    0.000    0.013    0.000 util.py:185(__len__)
#     42928    0.010    0.000    0.010    0.000 util.py:182(__getitem__)
#     57805    0.009    0.000    0.009    0.000 reex.py:2469(ewp)
#      2178    0.002    0.000    0.009    0.000 reex_ext.py:1242(__hash__)
#     42125    0.006    0.000    0.006    0.000 reex.py:1643(epsilonP)
#     18206    0.003    0.000    0.003    0.000 reex.py:1617(__repr__)
#       755    0.000    0.000    0.000    0.000 reex.py:1715(partialDerivatives)
#      1020    0.000    0.000    0.000    0.000 reex.py:1629(rpn)
#       407    0.000    0.000    0.000    0.000 reex.py:1670(ewp)
#       408    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {time.time}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
# Naive direct pd algorithm
def naive(self, word):
    current = set([self])
    for sigma in word:
        next = set()
        for pd in current:
            next.update(pd.partialDerivatives(sigma))
        current = next
    for pd in current:
        if pd.ewp():
            return True
    return False

testit(naive)
# Out:
# Took 438.418345928 seconds
#          830354677 function calls (505872854 primitive calls) in 438.418 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       408    1.040    0.003  438.418    1.075 <ipython-input-10-c491571a2f3b>:2(naive)
# 2675125/317171    6.743    0.000  436.299    0.001 reex_ext.py:340(partialDerivatives)
#   2356354    1.083    0.000  410.256    0.000 {method 'add' of 'set' objects}
#   2351714    1.275    0.000  409.274    0.000 reex.py:378(__hash__)
# 212908200/2465160   62.599    0.000  406.513    0.000 {repr}
# 92433523/2192639   65.859    0.000  404.823    0.000 reex.py:1863(__repr__)
# 10664090/5876645    6.932    0.000  293.467    0.000 reex_ext.py:641(__repr__)
# 10664090/5876645    4.378    0.000  289.628    0.000 reex.py:2530(__repr__)
#  76309086   43.384    0.000  228.784    0.000 reex_ext.py:912(__repr__)
#  84030633  121.280    0.000  183.835    0.000 reex_ext.py:900(__str__)
# 14911904/12707190    9.406    0.000  107.199    0.000 reex_ext.py:750(__repr__)
# 14911904/12707190    6.054    0.000   99.145    0.000 reex.py:2372(__repr__)
#  84030633   32.486    0.000   32.486    0.000 {hasattr}
#  84030633   30.069    0.000   30.069    0.000 {method 'encode' of 'unicode' objects}
#   7716499    4.183    0.000   21.515    0.000 reex_ext.py:1108(__repr__)
#  76309086   18.912    0.000   18.912    0.000 {method 'format' of 'str' objects}
# 371425/171883    0.461    0.000   12.121    0.000 reex.py:2084(partialDerivatives)
#    204165    0.245    0.000    8.440    0.000 reex_ext.py:596(partialDerivatives)
#    988507    1.317    0.000    6.486    0.000 reex_ext.py:918(partialDerivatives)
#   2037555    1.697    0.000    6.062    0.000 reex_ext.py:308(__init__)
# 8154174/2050689    3.262    0.000    4.991    0.000 reex.py:2802(ewp)
#   2037555    2.115    0.000    4.365    0.000 reex.py:1857(__init__)
#   3401492    2.213    0.000    3.521    0.000 reex_ext.py:11(__init__)
#    699038    0.683    0.000    2.573    0.000 reex_ext.py:915(derivative)
#   2732192    2.477    0.000    2.477    0.000 {hash}
# 1962771/976417    1.207    0.000    2.117    0.000 reex.py:2006(ewp)
#   1363937    0.837    0.000    2.107    0.000 reex.py:1383(__init__)
# 95708/90660    0.059    0.000    1.895    0.000 reex.py:2460(partialDerivatives)
#    750860    0.499    0.000    1.629    0.000 reex_ext.py:818(__init__)
#    613077    0.449    0.000    1.427    0.000 reex_ext.py:879(__init__)
#   3401492    1.308    0.000    1.308    0.000 reex.py:54(__init__)
#    989352    0.200    0.000    1.201    0.000 {method 'update' of 'set' objects}
#     80599    0.095    0.000    1.093    0.000 reex_ext.py:1114(derivative)
#     56723    0.066    0.000    1.001    0.000 reex.py:367(__eq__)
#  10762340    0.971    0.000    0.971    0.000 reex_ext.py:1236(__repr__)
#     80599    0.093    0.000    0.824    0.000 reex_ext.py:1111(__contains__)
#     80599    0.117    0.000    0.731    0.000 util.py:212(indexOf)
#    208870    0.122    0.000    0.586    0.000 reex_ext.py:1245(derivative)
#   4328158    0.491    0.000    0.491    0.000 reex.py:328(ewp)
#     80599    0.273    0.000    0.476    0.000 util.py:191(search)
#   2356354    0.279    0.000    0.279    0.000 reex.py:133(emptysetP)
#   2037555    0.219    0.000    0.219    0.000 reex.py:322(epsilonP)
#    375430    0.161    0.000    0.216    0.000 reex.py:1634(__hash__)
# 322396/161198    0.134    0.000    0.201    0.000 {len}
#   1459085    0.189    0.000    0.189    0.000 reex.py:2691(ewp)
#    699038    0.172    0.000    0.172    0.000 reex_ext.py:936(__contains__)
#     80599    0.073    0.000    0.138    0.000 util.py:221(indexContains)
#    161198    0.068    0.000    0.091    0.000 util.py:185(__len__)
#    302232    0.066    0.000    0.066    0.000 util.py:182(__getitem__)
#    339261    0.051    0.000    0.051    0.000 reex.py:2469(ewp)
#    318799    0.044    0.000    0.044    0.000 reex.py:1643(epsilonP)
#      5048    0.004    0.000    0.020    0.000 reex_ext.py:1242(__hash__)
#    110758    0.016    0.000    0.016    0.000 reex.py:1617(__repr__)
#       845    0.000    0.000    0.000    0.000 reex.py:1715(partialDerivatives)
#       407    0.000    0.000    0.000    0.000 reex.py:1670(ewp)
#         2    0.000    0.000    0.000    0.000 {time.time}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
# direct PD algorithm, my best attempt
testit(lambda re, word: re.evalWordP_PD_Optimized(word))
# Out:
# Took 4.69163608551 seconds
#          7776523 function calls (6467406 primitive calls) in 4.691 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       408    0.095    0.000    4.691    0.011 <ipython-input-11-dc048676e88e>:2(<lambda>)
#       408    0.430    0.001    4.596    0.011 reex_ext.py:149(evalWordP_PD_Optimized)
# 344463/41711    1.114    0.000    3.817    0.000 reex_ext.py:353(partialDerivativesRPN)
# 63015/23655    0.075    0.000    1.170    0.000 reex_ext.py:489(partialDerivativesRPN)
#    151999    0.190    0.000    1.027    0.000 reex_ext.py:923(partialDerivativesRPN)
#    258771    0.272    0.000    0.755    0.000 reex_ext.py:308(__init__)
# 992856/255141    0.388    0.000    0.621    0.000 reex.py:2802(ewp)
#     30181    0.050    0.000    0.511    0.000 reex_ext.py:608(partialDerivativesRPN)
#    259179    0.234    0.000    0.485    0.000 reex.py:1857(__init__)
#    463426    0.291    0.000    0.451    0.000 reex_ext.py:11(__init__)
# 17144/14966    0.010    0.000    0.386    0.000 reex_ext.py:747(partialDerivativesRPN)
#    106132    0.089    0.000    0.374    0.000 reex_ext.py:915(derivative)
#    204247    0.130    0.000    0.331    0.000 reex.py:1383(__init__)
# 273523/129093    0.166    0.000    0.299    0.000 reex.py:2006(ewp)
#    104496    0.112    0.000    0.276    0.000 reex_ext.py:818(__init__)
#     99751    0.075    0.000    0.242    0.000 reex_ext.py:879(__init__)
#       408    0.002    0.000    0.177    0.000 reex_ext.py:533(compress)
#    463426    0.160    0.000    0.160    0.000 reex.py:54(__init__)
#     33698    0.019    0.000    0.140    0.000 reex_ext.py:1245(derivative)
#     12169    0.012    0.000    0.131    0.000 reex_ext.py:1114(derivative)
# 13464/816    0.021    0.000    0.118    0.000 reex_ext.py:563(_memoRPN)
# 14280/408    0.023    0.000    0.111    0.000 reex_ext.py:470(_memoRPN)
#  2448/408    0.003    0.000    0.107    0.000 reex_ext.py:729(_memoRPN)
#     12169    0.008    0.000    0.090    0.000 reex_ext.py:1111(__contains__)
#    428394    0.089    0.000    0.089    0.000 {method 'update' of 'dict' objects}
#     52248    0.042    0.000    0.082    0.000 reex_ext.py:873(_memoRPN)
#     12169    0.011    0.000    0.081    0.000 util.py:212(indexOf)
#    548168    0.073    0.000    0.073    0.000 {method 'items' of 'dict' objects}
#    566369    0.066    0.000    0.066    0.000 reex.py:328(ewp)
#    176280    0.061    0.000    0.061    0.000 {hasattr}
#    625892    0.059    0.000    0.059    0.000 {method 'has_key' of 'dict' objects}
# 12648/408    0.013    0.000    0.056    0.000 reex_ext.py:557(_delAttr)
#     27744    0.016    0.000    0.053    0.000 reex_ext.py:1051(_memoRPN)
# 14280/408    0.015    0.000    0.053    0.000 reex_ext.py:464(_delAttr)
#  2448/408    0.002    0.000    0.050    0.000 reex_ext.py:724(_delAttr)
#     12169    0.030    0.000    0.050    0.000 util.py:191(search)
#    300896    0.035    0.000    0.035    0.000 reex.py:133(emptysetP)
# 4488/3672    0.004    0.000    0.031    0.000 reex_ext.py:811(_memoRPN)
#     29010    0.018    0.000    0.030    0.000 reex_ext.py:1044(rpn)
#    258771    0.029    0.000    0.029    0.000 reex.py:322(epsilonP)
#    106132    0.026    0.000    0.026    0.000 reex_ext.py:936(__contains__)
#    197967    0.024    0.000    0.024    0.000 reex.py:2691(ewp)
# 48676/24338    0.013    0.000    0.022    0.000 {len}
#     12169    0.010    0.000    0.020    0.000 util.py:221(indexContains)
#     27336    0.010    0.000    0.015    0.000 reex_ext.py:1047(_delAttr)
# 4488/3672    0.003    0.000    0.015    0.000 reex_ext.py:806(_delAttr)
#     24338    0.009    0.000    0.012    0.000 util.py:185(__len__)
#     52248    0.009    0.000    0.009    0.000 reex.py:1629(rpn)
#     42928    0.008    0.000    0.008    0.000 util.py:182(__getitem__)
#     29010    0.008    0.000    0.008    0.000 {method 'replace' of 'unicode' objects}
#     57805    0.008    0.000    0.008    0.000 reex.py:2469(ewp)
#     43229    0.007    0.000    0.007    0.000 {method 'values' of 'dict' objects}
#      1094    0.001    0.000    0.006    0.000 reex.py:2563(rpn)
#     61200    0.006    0.000    0.006    0.000 {delattr}
#     42125    0.005    0.000    0.005    0.000 reex.py:1643(epsilonP)
#     29010    0.005    0.000    0.005    0.000 {repr}
#       290    0.000    0.000    0.003    0.000 reex.py:2797(rpn)
#       290    0.000    0.000    0.003    0.000 reex.py:2397(rpn)
#       408    0.001    0.000    0.002    0.000 reex_ext.py:478(__init__)
#       290    0.000    0.000    0.002    0.000 reex.py:2003(rpn)
#       290    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#       755    0.000    0.000    0.000    0.000 reex_ext.py:829(partialDerivativesRPN)
#       407    0.000    0.000    0.000    0.000 reex.py:1670(ewp)
#         2    0.000    0.000    0.000    0.000 {time.time}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
